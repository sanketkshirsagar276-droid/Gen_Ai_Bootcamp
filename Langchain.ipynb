# %%
pip install -U "langchain[google-genai]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.9.0 which is incompatible.
# ...

# %%
import os

os.environ["OPENAI_API_KEY"] = ""

from langchain_google_genai.llms import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model='gemini-2.0-pro')

# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = "AIzaSyDOLNY7gIbOAPMsr6OHljwpp1-FHG7mOec"

from langchain.chat_models import init_chat_model

model = ChatGoogleGenerativeAI(model='gemini-2.0-flash-lite')

# %%
model.invoke("Who is ai")
# Out:
# AIMessage(content='AI, or Artificial Intelligence, refers to the simulation of human intelligence processes by computer systems. These processes include learning (the acquisition of information and rules for using the information), reasoning (using the rules to reach approximate or definite conclusions), and self-correction.\n\nHere\'s a breakdown of what that means:\n\n*   **It\'s about computers:** AI is created and runs on computers.\n*   **It imitates humans:** The goal of AI is to make computers think and act in ways that are similar to how humans do.\n*   **It involves learning:** AI systems can learn from data, improving their performance over time.\n*   **It involves reasoning:** AI systems can use what they\'ve learned to solve problems and make decisions.\n*   **It\'s constantly evolving:** AI is a rapidly developing field, with new advancements happening all the time.\n\n**Key areas within AI include:**\n\n*   **Machine Learning (ML):** This is a subset of AI that focuses 
# ...

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyDOLNY7gIbOAPMsr6OHljwpp1-FHG7mOec")

model = genai.GenerativeModel("gemini-2.5-flash")
#model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17") # This is the latest model as of 2024-04-17

response = model.generate_content("can you build summarization table between ai vs gen ai vs agentic ai ")
print(response.text)
# Out:
# Here's a summarization table comparing Artificial Intelligence (AI), Generative AI (Gen AI), and Agentic AI, highlighting their core differences, capabilities, and evolutionary relationships:
#
# ## AI vs. Gen AI vs. Agentic AI: A Summarization Table
#
# | Feature                  | **AI (Artificial Intelligence)**                                    | **Generative AI (Gen AI)**                                                | **Agentic AI (Agentic Artificial Intelligence)**                              |
# | :----------------------- | :------------------------------------------------------------------ | :------------------------------------------------------------------------ | :--------------------------------------------------------------------------- |
# ...
